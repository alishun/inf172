# %%
import pandas as pd
from kmodes.kprototypes import KPrototypes

# %%
df = pd.read_csv('dataset.csv')
df_strings = ['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE', 'SCC', 'CALC', 'MTRANS']

# Calculate BMI and drop height, weight columns
df['BMI'] = df['Weight'] / (df['Height'] ** 2)

df.drop('Height', axis=1, inplace=True)
df.drop('Weight', axis=1, inplace=True)

# %%
df
# Out:
#       Gender        Age family_history_with_overweight FAVC  FCVC  NCP  \
# 0     Female  21.000000                            yes   no   2.0  3.0
# 1     Female  21.000000                            yes   no   3.0  3.0
# 2       Male  23.000000                            yes   no   2.0  3.0
# 3       Male  27.000000                             no   no   3.0  3.0
# 4       Male  22.000000                             no   no   2.0  1.0
# ...      ...        ...                            ...  ...   ...  ...
# 2106  Female  20.976842                            yes  yes   3.0  3.0
# 2107  Female  21.982942                            yes  yes   3.0  3.0
# 2108  Female  22.524036                            yes  yes   3.0  3.0
# 2109  Female  24.361936                            yes  yes   3.0  3.0
# 2110  Female  23.664709                            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF       TUE        CALC  \
# ...

# %%
X = df.drop(columns = ['NObeyesdad'])

# %%
kproto = KPrototypes(n_clusters=7)

# Fit the model
clusters = kproto.fit_predict(X, categorical=[2, 3])

# Assign the cluster labels to the original DataFrame
df['Cluster'] = clusters
# Out:
# ---------------------------------------------------------
# ValueError              Traceback (most recent call last)
# Cell In[6], line 4
#       1 kproto = KPrototypes(n_clusters=7, init='Huang', n_init=5, verbose=2)
#       3 # Fit the model
# ----> 4 clusters = kproto.fit_predict(X, categorical=[2, 3])
#       6 # Assign the cluster labels to the original DataFrame
#       7 df['Cluster'] = clusters
#
# File ~\OneDrive\Documents\inf172\inf172\venv\lib\site-packages\kmodes\kmodes.py:154, in KModes.fit_predict(self, X, y, **kwargs)
#     148 def fit_predict(self, X, y=None, **kwargs):
#     149     """Compute cluster centroids and predict cluster index for each sample.
#     150
#     151     Convenience method; equivalent to calling fit(X) followed by
#     152     predict(X).
#     153     """
# --> 154     return self.fit(X, **kwargs).predict(X, **kwargs)
#
# ...

# %%
centroids = kproto.cluster_centroids_
center_df = pd.DataFrame(centroids, columns=df.columns)  # Exclude the 'Cluster' column
center_df['Cluster'] = center_df['Cluster'].round().astype(int)

print(center_df)
